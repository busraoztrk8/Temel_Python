# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1=np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2=numpyDizisi1**2

# %%
(benimfigur,benimEksen)=plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,color="#3A95A8",alpha=0.3)
benimEksen.plot(numpyDizisi2,numpyDizisi1,color="#C96F23")
#diğer renkleri bulmak için google'a rgb hex code
#saydam yapmak için aplha=0.3

# %%
(yeniFigur,yeniEksen)=plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 2,color="blue",linewidth=1.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1 + 3,color="yellow",linewidth=1.0)
#linewidth:çizgi kalınlığı

yeniEksen.plot(numpyDizisi1,numpyDizisi1+4,color="#C96F23",linestyle="--") #-. kullabiliriz
yeniEksen.plot(numpyDizisi1,numpyDizisi1+5,color="#C96F23",linestyle=":")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+6,color="#C96F23",linestyle="--")

yeniEksen.plot(numpyDizisi1,numpyDizisi1+7,color="#000000",linestyle="--", marker="o",markersize=4,markerfacecolor="red",)

# %% [markdown]
# # scatter(dağıtılmış)

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# # histogram

# %%
yeniDİzi=np.random.randint(0,100,50)

# %%
yeniDİzi
# Out:
# array([ 4, 73, 52, 96,  8, 66, 34, 87, 96, 84, 25, 60, 94, 27, 21, 89, 67,
#        13, 23, 32, 46, 30, 63, 93, 81,  7, 37, 32, 86, 88, 63,  4, 96, 89,
#        38, 75, 85, 75, 28, 35, 56, 55, 42, 56, 54, 61, 85, 20, 69, 60])

# %%
plt.hist(yeniDİzi)
# Out:
# (array([5., 2., 5., 6., 2., 5., 7., 4., 5., 9.]),
#  array([ 4. , 13.2, 22.4, 31.6, 40.8, 50. , 59.2, 68.4, 77.6, 86.8, 96. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # boxplot
# ##standart sapmanın olduğunu gösterir

# %%
plt.boxplot(yeniDİzi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20fb5452750>,
#   <matplotlib.lines.Line2D at 0x20fb545d910>],
#  'caps': [<matplotlib.lines.Line2D at 0x20fb5460890>,
#   <matplotlib.lines.Line2D at 0x20fb5463950>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20fb5215010>],
#  'medians': [<matplotlib.lines.Line2D at 0x20fb546a990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20fb5471590>],
#  'means': []}

# %%
plt.boxplot(yeniDİzi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20fb4af3050>,
#   <matplotlib.lines.Line2D at 0x20fb53d2c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x20fb53c6350>,
#   <matplotlib.lines.Line2D at 0x20fb52e2290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20fb52efc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x20fb5121490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20fb53180d0>],
#  'means': []}
